# %% [markdown]
# http://mirwalk.umm.uni-heidelberg.de/resources/

# %% [markdown]
# The binding site is determined using the RNAduplex programme from the ViennaRNA software package. RNAduplex forms intermolecular pairs and neglects the competition between intramolecular folding and hybridization. It is used as a pre-filter in the TarPmiR prediction software.
#
# More information:
# https://www.tbi.univie.ac.at/RNA/tutorial/#sec6_3

# %%
import pandas as pd
import numpy as np

# %%
db = pd.read_csv('/Users/Anna/Study/python/biopython/mirna/mirna db/hsa_miRWalk_3UTR.txt', delimiter = '\t')
db.head()
# Out:
#              miRNA          mRNA Genesymbol binding_site  \
# 0    hsa-let-7a-5p  NM_001256426     PDLIM5    4233,4272
# 1  hsa-let-7a-2-3p  NM_001256426     PDLIM5    3267,3297
# 2    hsa-let-7b-3p  NM_001256426     PDLIM5    2695,2717
# 3    hsa-let-7c-5p  NM_001256426     PDLIM5    2923,2946
# 4    hsa-let-7c-3p  NM_001256426     PDLIM5    3716,3747
#
#                                               duplex  binding_probability
# 0  TGAGGTAGTAGGTTGTATAGTT#AACTGAATACTTCTCCAATAGCA...             0.923077
# 1  CTGTACAGCCTCCTAGCTTTCC#AGTCCCATGTACTTGGGAGGCTG...             0.846154
# 2  CTATACAACCTACTGCCTTCCC#GAACCCGGGAGGGAGAGGTTGC#...             0.846154
# 3  TGAGGTAGTAGGTTGTATGGTT#ACCATATAGCTTATAAGTCTCAA...             0.923077
# 4  CTGTACAACCTTCTAGCTTTCC#GGAAAGCTTTTATTCACAGAGGT...             0.923077

# %%
db[db['Genesymbol']=='SPANXD']
# Out:
#                      miRNA       mRNA Genesymbol binding_site  \
# 6709225    hsa-miR-320a-3p  NM_032417     SPANXD      634,657
# 6709226     hsa-miR-377-5p  NM_032417     SPANXD      644,663
# 6709227    hsa-miR-550a-5p  NM_032417     SPANXD      634,658
# 6709228  hsa-miR-550a-3-5p  NM_032417     SPANXD      640,658
# 6709229       hsa-miR-320c  NM_032417     SPANXD      637,657
# 6709230    hsa-miR-1285-5p  NM_032417     SPANXD      649,677
# 6709231       hsa-miR-320d  NM_032417     SPANXD      640,657
# 6709232        hsa-miR-711  NM_032417     SPANXD      636,656
# 6709233      hsa-miR-3135a  NM_032417     SPANXD      634,658
# 6709234    hsa-miR-3192-5p  NM_032417     SPANXD      634,648
# 6709235       hsa-miR-3202  NM_032417     SPANXD      631,651
# 6709236       hsa-miR-3652  NM_032417     SPANXD      640,657
# 6709237     hsa-miR-676-3p  NM_032417     SPANXD      641,658
# 6709238  hsa-miR-550b-2-5p  NM_032417     SPANXD      640,658
# 6709239       hsa-miR-4518  NM_032417     SPANXD      633,657
# 6709240    hsa-miR-6749-5p  NM_032417     SPANXD      640,662
# 6709241    hsa-miR-6796-5p  NM_032417     SPANXD      633,659
# 6709242    hsa-miR-6814-5p  NM_032417     SPANXD      634,656
# 6709243    hsa-miR-6854-5p  NM_032417     SPANXD      642,657
# 6709244    hsa-miR-6886-5p  NM_032417     SPANXD      633,656
# 6709245    hsa-miR-7156-5p  NM_032417     SPANXD      658,678
# 6709246       hsa-miR-8078  NM_032417     SPANXD      640,663
# 6709247      hsa-miR-12127  NM_032417     SPANXD      646,681
#
#                                                     duplex  \
# 6709225  AAAAGCTGGGTTGAGAGGGCGA#GCTACATCTCTCAACCTTGGGCA...
# 6709226  AGAGGTTGCCCTTGGTGAATTC#TCAACCTTGGGCAATGACA#.(....
# 6709227  AGTGCCTGAGGGAGTAAGAGCCC#GCTACATCTCTCAACCTTGGGC...
# 6709228  AGTGCCTGAGGGAGTAAGAG#TCTCTCAACCTTGGGCAA#..((((...
# 6709229  AAAAGCTGGGTTGAGAGGGT#ACATCTCTCAACCTTGGGCA#.......
# 6709230  GATCTCACTTTGTTGCCCAGG#CTTGGGCAATGACAATAAAGTTTG...
# 6709231  AAAAGCTGGGTTGAGAGGA#TCTCTCAACCTTGGGCA#....((((...
# 6709232  GGGACCCAGGGAGAGACGTAAG#TACATCTCTCAACCTTGGGC#.....
# 6709233  TGCCTAGGCTGAGACTGCAGTG#GCTACATCTCTCAACCTTGGGCA...
# 6709234  TCTGGGAGGTTGTAGCAGTGGAA#GCTACATCTCTCAA#..(((((...
# 6709235  TGGAAGGGAGAAGAGCTTTAAT#GAAGCTACATCTCTCAACCT#.(...
# 6709236  CGGCTGGAGGTGTGAGGA#TCTCTCAACCTTGGGCA#..(((.(((...
# 6709237  CTGTCCTAAGGTTGTTGAGTT#CTCTCAACCTTGGGCAA#.((.((...
# 6709238  ATGTGCCTGAGGGAGTAAGACA#TCTCTCAACCTTGGGCAA#...(...
# 6709239  GCTCAGGGATGATAACTGTGCTGAGA#AGCTACATCTCTCAACCTT...
# 6709240  TCGGGCCTGGGGTTGGGGGAGC#TCTCTCAACCTTGGGCAATGAC#...
# 6709241  TTGTGGGGTTGGAGAGCTGGCTG#AGCTACATCTCTCAACCTTGGG...
# 6709242  TCCCAAGGGTGAGATGCTGCCA#GCTACATCTCTCAACCTTGGGC#...
# 6709243  AAGCTCAGGTTTGAGAACTGCTGA#TCTCAACCTTGGGCA#..(((...
# 6709244  CCCGCAGGTGAGATGAGGGCT#AGCTACATCTCTCAACCTTGGGC#...
# 6709245  TTGTTCTCAAACTGGCTGTCAGA#TGACAATAAAGTTTGAGAAG#....
# 6709246  GGTCTAGGCCCGGTGAGAGACTC#TCTCTCAACCTTGGGCAATGAC...
# 6709247  TAGAGGTTCTAATGGTCCAGGGTTA#AACCTTGGGCAATGACAATA...
#
#          binding_probability
# 6709225             0.846154
# 6709226             0.846154
# 6709227             0.923077
# 6709228             0.923077
# 6709229             0.871795
# 6709230             1.000000
# 6709231             0.923077
# 6709232             1.000000
# 6709233             0.846154
# 6709234             1.000000
# 6709235             0.846154
# 6709236             0.923077
# 6709237             1.000000
# 6709238             0.846154
# 6709239             0.961538
# 6709240             0.846154
# 6709241             0.923077
# 6709242             0.923077
# 6709243             1.000000
# 6709244             0.980769
# 6709245             0.846154
# 6709246             0.846154
# 6709247             0.923077

# %%
db_mod = db.copy()

# %%
db_mod['duplex'] = db_mod['duplex'].apply(lambda x: x.split('#'))

# %%
db_mod['d1_miRNAseq'] = db_mod['duplex'].apply(lambda x: x[0])
db_mod['d2_mRNA_bind_site'] = db_mod['duplex'].apply(lambda x: x[1])

# %% [markdown]
# d1 - miRNA seq

# %% [markdown]
# UGAGGUAGUAGGUUGUAUAGUU
# TGAGGTAGTAGGTTGTATAGTT

# %% [markdown]
# "&" character as separator.
# ”.” denotes bases that are essentially unpaired
# ”,” weakly paired
# ”|”strongly paired without preference
# ”{},()” weakly ( >33%) upstream (downstream) paired or strongly ( >66%) up-/downstream paired bases, respectively.

# %%
db_mod.drop('duplex', axis=1, inplace=True)

# %%
df_lib = db_mod.groupby('miRNA', as_index=False)['d1_miRNAseq'].value_counts()
df_lib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2656 entries, 0 to 2655
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   miRNA        2656 non-null   object
#  1   d1_miRNAseq  2656 non-null   object
#  2   count        2656 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 62.4+ KB

# %%
df_lib.nunique()
# Out:
# miRNA          2656
# d1_miRNAseq    2632
# count          2518
# dtype: int64

# %%
duplicates = df_lib[df_lib.duplicated(subset='d1_miRNAseq', keep=False)==True].sort_values(by='d1_miRNAseq')
display(duplicates)
display(duplicates.info())
# Out:
#                   miRNA                d1_miRNAseq  count
# 1776    hsa-miR-548t-3p  AAAAACCACAATTACTTTTGCACCA   3586
# 1706      hsa-miR-548aa  AAAAACCACAATTACTTTTGCACCA   3586
# 1772    hsa-miR-548o-5p     AAAAGTAATTGCGGTTTTTGCC   2265
# 1753    hsa-miR-548c-5p     AAAAGTAATTGCGGTTTTTGCC   2265
# 1722   hsa-miR-548am-5p     AAAAGTAATTGCGGTTTTTGCC   2265
# 1712   hsa-miR-548ae-5p       AAAAGTAATTGTGGTTTTTG    378
# 1710   hsa-miR-548ad-5p       AAAAGTAATTGTGGTTTTTG    378
# 1866     hsa-miR-570-5p     AAAGGTAATTGCAGTTTTTCCC   5628
# 1716      hsa-miR-548ai     AAAGGTAATTGCAGTTTTTCCC   5628
# 414     hsa-miR-199a-3p     ACAGTAGTCTGCACATTGGTTA  10394
# 416     hsa-miR-199b-3p     ACAGTAGTCTGCACATTGGTTA  10394
# 1620    hsa-miR-517a-3p     ATCGTGCATCCCTTTAGAGTGT  10247
# 1621    hsa-miR-517b-3p     ATCGTGCATCCCTTTAGAGTGT  10247
# 1762    hsa-miR-548h-3p    CAAAAACCGCAATTACTTTTGCA   1387
# 1784       hsa-miR-548z    CAAAAACCGCAATTACTTTTGCA   1387
# 1651  hsa-miR-519a-2-5p      CCTCTACAGGGAAGCGCTTTC  13904
# 1665    hsa-miR-520b-5p      CCTCTACAGGGAAGCGCTTTC  13904
# 1687    hsa-miR-526a-5p     CTCTAGAGGGAAGCACTTTCTG  17261
# 1635    hsa-miR-518d-5p     CTCTAGAGGGAAGCACTTTCTG  17261
# 1667    hsa-miR-520c-5p     CTCTAGAGGGAAGCACTTTCTG  17261
# 1681     hsa-miR-523-5p     CTCTAGAGGGAAGCGCTTTCTG  17623
# 1679     hsa-miR-522-5p     CTCTAGAGGGAAGCGCTTTCTG  17623
# 1657    hsa-miR-519c-5p     CTCTAGAGGGAAGCGCTTTCTG  17623
# 1653    hsa-miR-519a-5p     CTCTAGAGGGAAGCGCTTTCTG  17623
# 1655    hsa-miR-519b-5p     CTCTAGAGGGAAGCGCTTTCTG  17623
# 1637    hsa-miR-518e-5p     CTCTAGAGGGAAGCGCTTTCTG  17623
# 1690        hsa-miR-527       CTGCAAAGGGAAGCCCTTTC  13676
# 1630    hsa-miR-518a-5p       CTGCAAAGGGAAGCCCTTTC  13676
# 849       hsa-miR-3689c     CTGGGAGGTGTGATATTGTGGT  26540
# 847    hsa-miR-3689b-3p     CTGGGAGGTGTGATATTGTGGT  26540
# 803     hsa-miR-365a-3p     TAATGCCCCTAAAAATCCTTAT   5774
# 805     hsa-miR-365b-3p     TAATGCCCCTAAAAATCCTTAT   5774
# 1782    hsa-miR-548x-5p    TGCAAAAGTAATTGCAGTTTTTG   1637
# 1718   hsa-miR-548aj-5p    TGCAAAAGTAATTGCAGTTTTTG   1637
# 1761    hsa-miR-548g-5p    TGCAAAAGTAATTGCAGTTTTTG   1637
# 1617    hsa-miR-516b-3p         TGCTTCCTTTCAGAGGGT  14336
# 1615    hsa-miR-516a-3p         TGCTTCCTTTCAGAGGGT  14336
# 851       hsa-miR-3689e     TGTGATATCATGGTTCCTGGGA  16385
# 848    hsa-miR-3689b-5p     TGTGATATCATGGTTCCTGGGA  16385
# 846    hsa-miR-3689a-5p     TGTGATATCATGGTTCCTGGGA  16385
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 1776 to 846
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   miRNA        40 non-null     object
#  1   d1_miRNAseq  40 non-null     object
#  2   count        40 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.2+ KB
# None

# %%
mirna_seq_clean = df_lib.drop_duplicates(subset='d1_miRNAseq', keep=False, ignore_index=True)
display(mirna_seq_clean)
display(mirna_seq_clean.nunique())
# Out:
#                 miRNA             d1_miRNAseq  count
# 0     hsa-let-7a-2-3p  CTGTACAGCCTCCTAGCTTTCC  20958
# 1       hsa-let-7a-3p   CTATACAATCTACTGTCTTTC   1353
# 2       hsa-let-7a-5p  TGAGGTAGTAGGTTGTATAGTT  16373
# 3       hsa-let-7b-3p  CTATACAACCTACTGCCTTCCC  14363
# 4       hsa-let-7b-5p  TGAGGTAGTAGGTTGTGTGGTT  23817
# ...               ...                     ...    ...
# 2611     hsa-miR-9986    TGTGAGGTTGTCATGCCTGC  19479
# 2612   hsa-miR-99a-3p  CAAGCTCGCTTCTATGGGTCTG  17268
# 2613   hsa-miR-99a-5p  AACCCGTAGATCCGATCTTGTG   6074
# 2614   hsa-miR-99b-3p  CAAGCTCGTGTCTGTGGGTCCG  19293
# 2615   hsa-miR-99b-5p  CACCCGTAGAACCGACCTTGCG   8661
#
# [2616 rows x 3 columns]
# miRNA          2616
# d1_miRNAseq    2616
# count          2503
# dtype: int64

# %%
mirna_seq_clean['n'] = 8
# Out:
# /var/folders/f8/q9zbymw9785b7wb9qx0sclfw0000gn/T/ipykernel_7599/2050154703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mirna_seq_clean['n'] = 8

# %%
from random import choice
def string(length):
    DNA=""
    for count in range(length):
        DNA+=choice("CGTA")
    return DNA

string(8)
# Out:
# 'TCTCTCAA'

# %%
seq = []
a = string(8)
seq.append(a)

for el in range(len(mirna_seq_clean['n'].index)):
    b = string(mirna_seq_clean.loc[el]['n'])
    while b in seq:
        b = string(mirna_seq_clean.loc[el]['n']) 
    seq.append(b)

print(len(seq))
# Out:
# 2617

# %%
seq_df = pd.DataFrame(seq, columns = ['barcode'])

seq_df.nunique()
# Out:
# barcode    2617
# dtype: int64

# %%
final_df = pd.concat([mirna_seq_clean,seq_df], axis = 1)
display(final_df.head())
display(final_df.nunique())
display(final_df.info())
# Out:
#              miRNA             d1_miRNAseq    count    n   barcode
# 0  hsa-let-7a-2-3p  CTGTACAGCCTCCTAGCTTTCC  20958.0  8.0  CCTGGGAA
# 1    hsa-let-7a-3p   CTATACAATCTACTGTCTTTC   1353.0  8.0  CGGAGCAA
# 2    hsa-let-7a-5p  TGAGGTAGTAGGTTGTATAGTT  16373.0  8.0  GATGTGGG
# 3    hsa-let-7b-3p  CTATACAACCTACTGCCTTCCC  14363.0  8.0  GATCTCCT
# 4    hsa-let-7b-5p  TGAGGTAGTAGGTTGTGTGGTT  23817.0  8.0  ACAGGCGT
# miRNA          2616
# d1_miRNAseq    2616
# count          2503
# n                 1
# barcode        2617
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2617 entries, 0 to 2616
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   miRNA        2616 non-null   object
#  1   d1_miRNAseq  2616 non-null   object
#  2   count        2616 non-null   float64
#  3   n            2616 non-null   float64
#  4   barcode      2617 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 122.7+ KB
# None

# %%
final_df.drop([2616], axis=0, inplace=True)
final_df.drop(['n'], axis=1, inplace=True)

# %%
final_df['len_miRNA'] = final_df['d1_miRNAseq'].apply(lambda x: len(x))

# %%
display(final_df.head())
display(final_df.nunique())
# Out:
#              miRNA             d1_miRNAseq    count   barcode  len_miRNA
# 0  hsa-let-7a-2-3p  CTGTACAGCCTCCTAGCTTTCC  20958.0  CCTGGGAA         22
# 1    hsa-let-7a-3p   CTATACAATCTACTGTCTTTC   1353.0  CGGAGCAA         21
# 2    hsa-let-7a-5p  TGAGGTAGTAGGTTGTATAGTT  16373.0  GATGTGGG         22
# 3    hsa-let-7b-3p  CTATACAACCTACTGCCTTCCC  14363.0  GATCTCCT         22
# 4    hsa-let-7b-5p  TGAGGTAGTAGGTTGTGTGGTT  23817.0  ACAGGCGT         22
# miRNA          2616
# d1_miRNAseq    2616
# count          2503
# barcode        2616
# len_miRNA        13
# dtype: int64

# %%
mask = ['count', 'barcode', 'len_miRNA']
mirna_seq = final_df.drop(mask, axis = 1)
mirna_seq['start_utr_spanxd'] = ('caagaagc').upper()
mirna_seq['barcode'] = 'NNNNNNNN'
mirna_seq['end_utr_spanxd'] = ('aatgacaataaagtttgagaagctga').upper()
mirna_seq['link'] = string(20)

# %%
mirna_seq = mirna_seq[['miRNA', 'start_utr_spanxd', 'd1_miRNAseq', 'barcode', 'end_utr_spanxd', 'link']]

# %%
mirna_seq
# Out:
#                 miRNA start_utr_spanxd             d1_miRNAseq   barcode  \
# 0     hsa-let-7a-2-3p         CAAGAAGC  CTGTACAGCCTCCTAGCTTTCC  NNNNNNNN
# 1       hsa-let-7a-3p         CAAGAAGC   CTATACAATCTACTGTCTTTC  NNNNNNNN
# 2       hsa-let-7a-5p         CAAGAAGC  TGAGGTAGTAGGTTGTATAGTT  NNNNNNNN
# 3       hsa-let-7b-3p         CAAGAAGC  CTATACAACCTACTGCCTTCCC  NNNNNNNN
# 4       hsa-let-7b-5p         CAAGAAGC  TGAGGTAGTAGGTTGTGTGGTT  NNNNNNNN
# ...               ...              ...                     ...       ...
# 2611     hsa-miR-9986         CAAGAAGC    TGTGAGGTTGTCATGCCTGC  NNNNNNNN
# 2612   hsa-miR-99a-3p         CAAGAAGC  CAAGCTCGCTTCTATGGGTCTG  NNNNNNNN
# 2613   hsa-miR-99a-5p         CAAGAAGC  AACCCGTAGATCCGATCTTGTG  NNNNNNNN
# 2614   hsa-miR-99b-3p         CAAGAAGC  CAAGCTCGTGTCTGTGGGTCCG  NNNNNNNN
# 2615   hsa-miR-99b-5p         CAAGAAGC  CACCCGTAGAACCGACCTTGCG  NNNNNNNN
#
#                   end_utr_spanxd                  link
# 0     AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 1     AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 2     AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 3     AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 4     AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# ...                          ...                   ...
# 2611  AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 2612  AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 2613  AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 2614  AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
# 2615  AATGACAATAAAGTTTGAGAAGCTGA  ACCAGTACAAGCAAATGCTA
#
# [2616 rows x 6 columns]

# %%
#скачать после уточнения utr
mirna_seq.to_excel('/Users/Anna/Study/python/biopython/mirna/mirna db/final.mirna_seq.xlsx')
